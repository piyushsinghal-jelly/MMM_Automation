# %%
import streamlit as st

# Page title
st.title("My First Streamlit App")

# Text on the webpage
st.write("Welcome! This webpage was made with Python and Streamlit.")

# User input
name = st.text_input("What is your name?")

# Button action
if st.button("Say hello"):
    if name:
        st.success(f"Hello, {name}! 👋")
    else:
        st.warning("Please enter your name first.")

# Slider
number = st.slider("Choose a number", min_value=0, max_value=100, value=50)
st.write(f"You selected: {number}")
# Out:
# Running cells with '.venv (3.11.15) (Python 3.11.15)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/piyushsinghal/MMM/MMM_Automation/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
print("Streamlit app is running...")
