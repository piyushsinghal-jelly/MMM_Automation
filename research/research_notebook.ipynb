# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# Understanding the @ensure_annotations and Config_Box

# %%
example = {
    'key1': 'value1',
    'key2': 'value2',
    'key3': 'value3'
}

# %%
example['key1']
# Out:
# 'value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from box import ConfigBox
#
# ImportError: cannot import name 'ConfigBox' from 'box' (unknown location)

# %%
import sys
print(sys.executable)
# Out:
# /Users/piyushsinghal/MMM/MMM_Automation/.venv/bin/python

# %%
from box import ConfigBox
from box.exceptions import BoxValueError, BoxKeyError
